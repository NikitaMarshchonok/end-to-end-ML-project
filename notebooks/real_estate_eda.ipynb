# %%
import os
print(os.getcwd())
# Out:
# /Users/nikitamarshchonok/Desktop/end-to-end ML project/notebooks

# %%
import pandas as pd

# Load the dataset
real_estate_data = pd.read_csv('../data/Real_Estate.csv')

# Display the first few rows of the dataset and the info about the dataset
real_estate_data_head = real_estate_data.head()
data_info = real_estate_data.info()

print(real_estate_data_head)
print(data_info)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       3 # Load the dataset
#       4 real_estate_data = pd.read_csv("/data/Real_Estate.csv")
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# Out:
# Не удалось запустить ядро, так как среда Python ".venv" больше не доступна. Рассмотрите возможность выбрать другое ядро или обновить список сред Python.
